# %% [markdown]
# # Offline Exploration
#
# Use this notebook to experiment with preprocessing, feature extraction, and anomaly detection against the sample dataset. Replace `data/sample_weather_data.csv` with a richer dataset when available.

# %%
import pandas as pd

df = pd.read_csv("../data/sample_weather_data.csv", parse_dates=["timestamp"])
df.head()
